# %%
import pandas as pd
import geopandas as gd 
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
parks_data = pd.read_csv("Parks_Dataset.csv")

parks_data.head(25)
# Out:
#             id                                         name  \
# 0   2111959181                               Able Long Park
# 1   1109513049                      Albert Turk Graham Park
# 2   1544096765                                   Alcoa Park
# 3   1212681573                            Allegheny Commons
# 4    954863286                       Allegheny Landing Park
# 5    223959093                    Allegheny Riverfront Park
# 6   1596467340                          Alpine Gardens Park
# 7   1829922263                                   Alton Park
# 8   2049886968                               Amber Triangle
# 9   1047118140                                   Ammon Park
# 10  1928748922                               Arlington Park
# 11  1334547409                                Arlington Gym
# 12  1848662473                               Armstrong Park
# 13   485438954                                 Arsenal Park
# 14  1366899437                           August Wilson Park
# ...
